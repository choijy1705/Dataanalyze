# %%
import pandas as pd
import os

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/heart.csv')

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data.corr()
# Out:
#                age       sex        cp  ...        ca      thal    target
# age       1.000000 -0.098447 -0.068653  ...  0.276326  0.068001 -0.225439
# sex      -0.098447  1.000000 -0.049353  ...  0.118261  0.210041 -0.280937
# cp       -0.068653 -0.049353  1.000000  ... -0.181053 -0.161736  0.433798
# trestbps  0.279351 -0.056769  0.047608  ...  0.101389  0.062210 -0.144931
# chol      0.213678 -0.197912 -0.076904  ...  0.070511  0.098803 -0.085239
# fbs       0.121308  0.045032  0.094444  ...  0.137979 -0.032019 -0.028046
# restecg  -0.116211 -0.058196  0.044421  ... -0.072042 -0.011981  0.137230
# thalach  -0.398522 -0.044020  0.295762  ... -0.213177 -0.096439  0.421741
# exang     0.096801  0.141664 -0.394280  ...  0.115739  0.206754 -0.436757
# oldpeak   0.210013  0.096093 -0.149230  ...  0.222682  0.210244 -0.430696
# slope    -0.168814 -0.030711  0.119717  ... -0.080155 -0.104764  0.345877
# ca        0.276326  0.118261 -0.181053  ...  1.000000  0.151832 -0.391724
# thal      0.068001  0.210041 -0.161736  ...  0.151832  1.000000 -0.344029
# target   -0.225439 -0.280937  0.433798  ... -0.391724 -0.344029  1.000000
#
# [14 rows x 14 columns]

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data=data.corr(),annot=True,fmt='.2f')

# %% [markdown]
# ## 심장병 발생과 상관관계가 높은 항목
#
# * age
# * sex
# *   CP
# *   exang
# * oldpeak
# * slope
# * ca
# * thal

# %% [markdown]
# # age(나이)

# %%
data['age'].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77])

# %%
data['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='age',data = data, hue = 'sex')

# %% [markdown]
# **SEX(성별)**
#
# *   0 : 여성
# *   1 : 남성

# %%
data['sex'].unique()
# Out:
# array([1, 0])

# %%
data['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex', data=data, palette = 'mako_r')

# %%
pd.crosstab(data.sex, data.target).plot(kind = 'bar',figsize=(15,6))
plt.title('Heart disease frequency')
plt.legend(["Haven't disease",'Have disease'])
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# # cp(chest pain) - 가슴통증
#
# *  Value 1: typical angina
# *  Value 2: atypical angina
# * Value 3: non-anginal pain
# * Value 4: asymptomatic)

# %%
data['cp'].unique()
# Out:
# array([3, 2, 1, 0])

# %%
sns.countplot(x = 'cp', data=data)

# %% [markdown]
# # 모델링 생성

# %%
a = pd.get_dummies(data['cp'], prefix = 'cp')
b = pd.get_dummies(data['thal'], prefix = 'thal')
c = pd.get_dummies(data['slope'], prefix = 'slope')

# %%
frames = [data, a, b, c]
data = pd.concat(frames, axis =1)
data.head()
# Out:
#    age  sex  cp  trestbps  chol  ...  thal_2  thal_3  slope_0  slope_1  slope_2
# 0   63    1   3       145   233  ...       0       0        1        0        0
# 1   37    1   2       130   250  ...       1       0        1        0        0
# 2   41    0   1       130   204  ...       1       0        0        0        1
# 3   56    1   1       120   236  ...       1       0        0        0        1
# 4   57    0   0       120   354  ...       1       0        0        0        1
#
# [5 rows x 25 columns]

# %%
data = data.drop(columns = ['cp', 'thal', 'slope'])
data.head()
# Out:
#    age  sex  trestbps  chol  fbs  ...  thal_2  thal_3  slope_0  slope_1  slope_2
# 0   63    1       145   233    1  ...       0       0        1        0        0
# 1   37    1       130   250    0  ...       1       0        1        0        0
# 2   41    0       130   204    0  ...       1       0        0        0        1
# 3   56    1       120   236    0  ...       1       0        0        0        1
# 4   57    0       120   354    0  ...       1       0        0        0        1
#
# [5 rows x 22 columns]

# %%
y = data.target.values
x_data = data.drop(['target'], axis = 1)

# %% [markdown]
# ## 데이터 정규화 진행

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x = (x_data - np.min(x_data)) / (np.max(x_data) - np.min(x_data)).values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
x_train = x_train.T
y_train = y_train.T
x_test = x_test.T
y_test = y_test.T

# %%
# 초기화 진행
def initialize(dimension):

  weight = np.full((dimension,1), 0.01)
  bias = 0.0
  return weight, bias

# %% [markdown]
# ## 시그모이드 함수

# %%
def sigmoid(z):
  y_head = 1/(1+np.exp(-z))
  return y_head

# %% [markdown]
# ## 오차 역 전파법

# %%
def forwardBackward(weight, bias, x_train, y_train):
  # Forward
  y_head = sigmoid(np.dot(weight.T,x_train)+bias)
  loss = -(y_train*np.log(y_head) + (1-y_train)*np.log(1-y_head))
  cost = np.sum(loss) / x_train.shape[1]

  # Backward
  derivative_weight = np.dot(x_train, ((y_head-y_train).T))/x_train.shape[1]
  derivative_bias = np.sum(y_head-y_train)/x_train.shpae[1]
  gradients = {"Derivative_weight" : derivative_weight, "Derivative_bias ": derivative_bias}

  return cost, gradients

# %%
def update(weight,bias,x_train,y_train,learningRate,iteration) :
    costList = []
    index = []
    
    for i in range(iteration):
        cost,gradients = forwardBackward(weight,bias,x_train,y_train)
        weight = weight - learningRate * gradients["Derivative Weight"]
        bias = bias - learningRate * gradients["Derivative Bias"]
        
        costList.append(cost)
        index.append(i)

    parameters = {"weight": weight,"bias": bias}
    
    print("iteration:",iteration)
    print("cost:",cost)

    plt.plot(index,costList)
    plt.xlabel("Number of Iteration")
    plt.ylabel("Cost")
    plt.show()

    return parameters, gradients

# %%
def predict(weight,bias,x_test):
    z = np.dot(weight.T,x_test) + bias
    y_head = sigmoid(z)

    y_prediction = np.zeros((1,x_test.shape[1]))
    
    for i in range(y_head.shape[1]):
        if y_head[0,i] <= 0.5:
            y_prediction[0,i] = 0
        else:
            y_prediction[0,i] = 1
    return y_prediction

# %%
def logistic_regression(x_train,y_train,x_test,y_test,learningRate,iteration):
    dimension = x_train.shape[0]
    weight,bias = initialize(dimension)
    
    parameters, gradients = update(weight,bias,x_train,y_train,learningRate,iteration)

    y_prediction = predict(parameters["weight"],parameters["bias"],x_test)
    
    print("Manuel Test Accuracy: {:.2f}%".format((100 - np.mean(np.abs(y_prediction - y_test))*100)))

# %%
logistic_regression(x_train,y_train,x_test,y_test,1,100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-d90a3508c723> in <module>()
# ----> 1 logistic_regression(x_train,y_train,x_test,y_test,1,100)
#
# <ipython-input-34-099a2f060831> in logistic_regression(x_train, y_train, x_test, y_test, learningRate, iteration)
#       3     weight,bias = initialize(dimension)
#       4
# ----> 5     parameters, gradients = update(weight,bias,x_train,y_train,learningRate,iteration)
#       6
#       7     y_prediction = predict(parameters["weight"],parameters["bias"],x_test)
#
# <ipython-input-32-9127d10f5daa> in update(weight, bias, x_train, y_train, learningRate, iteration)
#       4
#       5     for i in range(iteration):
# ----> 6         cost,gradients = forwardBackward(weight,bias,x_train,y_train)
#       7         weight = weight - learningRate * gradients["Derivative Weight"]
#       8         bias = bias - learningRate * gradients["Derivative Bias"]
#
# <ipython-input-31-db4a5375303b> in forwardBackward(weight, bias, x_train, y_train)
#       7   # Backward
#       8   derivative_weight = np.dot(x_train, ((y_head-y_train).T))/x_train.shape[1]
# ----> 9   derivative_bias = np.sum(y_head-y_train)/x_train.shpae[1]
#      10   gradients = {"Derivative_weight" : derivative_weight, "Derivative_bias ": derivative_bias}
#      11
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'shpae'
