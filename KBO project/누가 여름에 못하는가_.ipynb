# %%
import pandas as pd

data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/baseball/KBO_2019_player_gamestats.csv', encoding='cp949')

# %%
data.head()
# Out:
#     팀     이름          생일     일자  상대  ...    OPS  투구  avLI  RE24    WPA
# 0  두산  페르난데스  1988-04-27  03-23  한화  ...  1.250  19  1.98  1.65  0.429
# 1  두산  페르난데스  1988-04-27  03-24  한화  ...  0.833   4  0.77 -0.36 -0.038
# 2  두산  페르난데스  1988-04-27  03-26  키움  ...  0.775  16  1.56  0.98  0.146
# 3  두산  페르난데스  1988-04-27  03-27  키움  ...  1.000  11  1.53  1.29  0.189
# 4  두산  페르난데스  1988-04-27  03-28  키움  ...  0.874  23  2.04 -0.30 -0.166
#
# [5 rows x 34 columns]

# %% [markdown]
# # 꾸준한 선수? VS 여름에 힘 떨어지는 선수

# %%
# '일자' 컬럼에서 월에 해당하는 값만 선택하여 '월' 컬럼을 추가하겠습니다. 
# 시리즈에서 반복문을 통해 하나씩 계산/점검을 진행하는 방식을 이용하였습니다. 

month_list = []

for month in data['일자']:
  li = month.split("-")
  month_list.append(li[0])

data['월'] = month_list

# %%
data.head()
# Out:
#     팀     이름          생일     일자  상대      결과  ...    OPS  투구  avLI  RE24    WPA   월
# 0  두산  페르난데스  1988-04-27  03-23  한화   W 5:4  ...  1.250  19  1.98  1.65  0.429  03
# 1  두산  페르난데스  1988-04-27  03-24  한화  L 1:11  ...  0.833   4  0.77 -0.36 -0.038  03
# 2  두산  페르난데스  1988-04-27  03-26  키움   W 7:2  ...  0.775  16  1.56  0.98  0.146  03
# 3  두산  페르난데스  1988-04-27  03-27  키움   W 3:2  ...  1.000  11  1.53  1.29  0.189  03
# 4  두산  페르난데스  1988-04-27  03-28  키움   L 4:5  ...  0.874  23  2.04 -0.30 -0.166  03
#
# [5 rows x 35 columns]

# %%
# 분석에 활용할 컬럼만 선택하겠습니다. 
columns_select = ['팀', '이름', '생일','일자', '상대','타수','안타','홈런', '루타', '타점','볼넷', '사구', '희비', '월']

data = data[columns_select]
data.head()
# Out:
#     팀     이름          생일     일자  상대  타수  안타  홈런  루타  타점  볼넷  사구  희비   월
# 0  두산  페르난데스  1988-04-27  03-23  한화   4   2   0   3   3   0   0   0  03
# 1  두산  페르난데스  1988-04-27  03-24  한화   2   0   0   0   0   0   0   0  03
# 2  두산  페르난데스  1988-04-27  03-26  키움   2   0   0   0   1   2   0   0  03
# 3  두산  페르난데스  1988-04-27  03-27  키움   4   3   0   3   1   0   0   0  03
# 4  두산  페르난데스  1988-04-27  03-28  키움   3   0   0   0   0   2   0   0  03

# %%
# 피벗 테이블을 이용해 월별 실적을 집계하겠습니다. 
# fill_value = 0 옵션을 이용해 데이터가 비어있는 경우 0을 입력하도록 하였습니다. (해당 월에 실적이 전혀 없으므로 0으로 정리)

data_player_month = data.pivot_table(index=['팀','이름', '생일','월'], values=['타수', '안타','홈런','루타','타점','볼넷','사구','희비'],aggfunc = sum, fill_value=0)
data_player_month
# Out:
#                        루타  볼넷  사구  안타   타수  타점  홈런  희비
# 팀   이름  생일         월
# KIA 고영창 1989-02-24 04   0   0   0   0    0   0   0   0
#     김선빈 1989-12-18 03   5   4   0   3   18   0   0   0
#                    04  17   3   0  13   44   6   0   0
#                    05  31  10   0  24   82  10   1   2
#                    06  29   8   1  24   81   8   1   0
# ...                    ..  ..  ..  ..  ...  ..  ..  ..
# 한화  호잉  1989-05-18 05  47   9   2  31  100  14   3   0
#                    06  41   4   1  23   93  13   4   0
#                    07  42   6   1  26   72  13   4   1
#                    08  41   4   1  26   94  13   3   0
#                    09   4   0   0   2   11   2   0   0
#
# [1261 rows x 8 columns]

# %%
# 현재 인덱스로 정리된 팀/이름/생일/월 데이터를 컬럼으로 변경하겠습니다
data_player_month = data_player_month.reset_index()
data_player_month
# Out:
#         팀   이름          생일   월  루타  볼넷  사구  안타   타수  타점  홈런  희비
# 0     KIA  고영창  1989-02-24  04   0   0   0   0    0   0   0   0
# 1     KIA  김선빈  1989-12-18  03   5   4   0   3   18   0   0   0
# 2     KIA  김선빈  1989-12-18  04  17   3   0  13   44   6   0   0
# 3     KIA  김선빈  1989-12-18  05  31  10   0  24   82  10   1   2
# 4     KIA  김선빈  1989-12-18  06  29   8   1  24   81   8   1   0
# ...   ...  ...         ...  ..  ..  ..  ..  ..  ...  ..  ..  ..
# 1256   한화   호잉  1989-05-18  05  47   9   2  31  100  14   3   0
# 1257   한화   호잉  1989-05-18  06  41   4   1  23   93  13   4   0
# 1258   한화   호잉  1989-05-18  07  42   6   1  26   72  13   4   1
# 1259   한화   호잉  1989-05-18  08  41   4   1  26   94  13   3   0
# 1260   한화   호잉  1989-05-18  09   4   0   0   2   11   2   0   0
#
# [1261 rows x 12 columns]

# %%
# 데이터프레임에 포함된 타자의 타율/출루율/장타율/OPS 데이터를 정리하는 함수입니다. 
def cal_hit(df):
    '''
    - 타율 : 공을 쳐서 나가는 비율 --> 안타 / 타수
    - 출루율: 진루해서 나가는 비율 -->  (안타+볼넷+몸에맞는볼)/(타수+볼넷+몸에맞는볼+희생플라이)
    - 장타율 : 타율에 진루한 베이스 가중치 추가 -->   루타 / 타수
    '''
    
    df['타율'] = df['안타'] / df['타수']
    df['출루율'] = (df['안타'] + df['볼넷'] + df['사구']) / (df['타수'] + df['사구'] + df['희비'])
    df['장타율'] = df['루타'] / df['타수']
    df['OPS'] = df['출루율'] + df['장타율']
    return df

# %%
# data_player_month  데이터의 타자별 주요 실적을 계산합니다. 

player_month_stat = cal_hit(data_player_month)
player_month_stat = player_month_stat.dropna()
player_month_stat
# Out:
#         팀   이름          생일   월  루타  ...  희비        타율       출루율       장타율       OPS
# 1     KIA  김선빈  1989-12-18  03   5  ...   0  0.166667  0.388889  0.277778  0.666667
# 2     KIA  김선빈  1989-12-18  04  17  ...   0  0.295455  0.363636  0.386364  0.750000
# 3     KIA  김선빈  1989-12-18  05  31  ...   2  0.292683  0.404762  0.378049  0.782811
# 4     KIA  김선빈  1989-12-18  06  29  ...   0  0.296296  0.402439  0.358025  0.760464
# 5     KIA  김선빈  1989-12-18  07  18  ...   0  0.358974  0.512821  0.461538  0.974359
# ...   ...  ...         ...  ..  ..  ...  ..       ...       ...       ...       ...
# 1256   한화   호잉  1989-05-18  05  47  ...   0  0.310000  0.411765  0.470000  0.881765
# 1257   한화   호잉  1989-05-18  06  41  ...   0  0.247312  0.297872  0.440860  0.738733
# 1258   한화   호잉  1989-05-18  07  42  ...   1  0.361111  0.445946  0.583333  1.029279
# 1259   한화   호잉  1989-05-18  08  41  ...   0  0.276596  0.326316  0.436170  0.762486
# 1260   한화   호잉  1989-05-18  09   4  ...   0  0.181818  0.181818  0.363636  0.545455
#
# [1142 rows x 16 columns]

# %%
# 월별 출류율 정리하겠습니다.
month_pivot = player_month_stat.pivot_table(index = ['팀','이름','생일'], values = '출루율', columns='월')
month_pivot = month_pivot.reset_index()
month_pivot
# Out:
# 월      팀   이름          생일        03  ...        07        08        09  10
# 0    KIA  김선빈  1989-12-18  0.388889  ...  0.512821  0.351648  0.414634 NaN
# 1    KIA  김주찬  1981-03-25  0.272727  ...  0.452381  0.405063  0.333333 NaN
# 2    KIA  나지완  1985-05-19  0.379310  ...  0.071429       NaN       NaN NaN
# 3    KIA  류승현  1997-07-01  0.000000  ...       NaN       NaN  0.277778 NaN
# 4    KIA  문경찬  1992-07-08  0.000000  ...       NaN       NaN       NaN NaN
# ..   ...  ...         ...       ...  ...       ...       ...       ...  ..
# 224   한화  최윤석  1987-03-28       NaN  ...       NaN       NaN       NaN NaN
# 225   한화  최재훈  1989-08-27  0.772727  ...  0.357143  0.437500  0.420290 NaN
# 226   한화  최진행  1985-08-17       NaN  ...       NaN       NaN  0.366667 NaN
# 227   한화  하주석  1994-02-25  0.263158  ...       NaN       NaN       NaN NaN
# 228   한화   호잉  1989-05-18  0.454545  ...  0.445946  0.326316  0.181818 NaN
#
# [229 rows x 11 columns]

# %% [markdown]
# # KBO 출루율 최고타자 불러오기

# %%
player_stat = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/baseball/player_stat.csv',encoding='cp949')
player_stat.head()
# Out:
#      팀   이름          생일   루타  볼넷  ...  희비        타율       출루율       장타율       OPS
# 0  KIA  김선빈  1989-12-18  146  43  ...   4  0.291878  0.398496  0.370558  0.769055
# 1  KIA  김주찬  1981-03-25  126  17  ...   3  0.299703  0.356522  0.373887  0.730409
# 2  KIA  나지완  1985-05-19   47  19  ...   2  0.186047  0.343284  0.364341  0.707625
# 3  KIA  류승현  1997-07-01   48   9  ...   0  0.253333  0.331169  0.320000  0.651169
# 4  KIA  박찬호  1995-06-05  160  26  ...   2  0.259921  0.315686  0.317460  0.633147
#
# [5 rows x 15 columns]

# %%
# 불러온 시즌 기록과, 월별 출루율 데이터를 병합합니다. 
df = pd.merge(player_stat, month_pivot, how = 'left', left_on=['팀','이름','생일'], right_on=['팀','이름','생일'])
df.head()
# Out:
#      팀   이름          생일   루타  볼넷  ...        06        07        08        09  10
# 0  KIA  김선빈  1989-12-18  146  43  ...  0.402439  0.512821  0.351648  0.414634 NaN
# 1  KIA  김주찬  1981-03-25  126  17  ...  0.361111  0.452381  0.405063  0.333333 NaN
# 2  KIA  나지완  1985-05-19   47  19  ...  0.533333  0.071429       NaN       NaN NaN
# 3  KIA  류승현  1997-07-01   48   9  ...  0.290909       NaN       NaN  0.277778 NaN
# 4  KIA  박찬호  1995-06-05  160  26  ...  0.322917  0.306452  0.233010  0.258824 NaN
#
# [5 rows x 23 columns]

# %%
# 출루율 실적을 기준으로 정렬하고, 출루율 상위 50인의 데이터만 가져오겠습니다
df_sort = df.sort_values(by='출루율',ascending=False).head(50)
df_sort
# Out:
#        팀     이름          생일   루타  ...        07        08        09        10
# 46    NC    나성범  1989-10-03   60  ...       NaN       NaN       NaN       NaN
# 10   KIA    최형우  1983-12-16  221  ...  0.509804  0.586207  0.611111       NaN
# 54    NC    양의지  1987-06-05  225  ...  0.625000  0.476190  0.451613  0.333333
# 15    KT    강백호  1999-07-29  217  ...       NaN  0.500000  0.437500       NaN
# 112   키움    박병호  1986-07-10  265  ...  0.400000  0.434343  0.472727  0.437500
# 99    삼성     러프  1986-07-28  243  ...  0.408451  0.411765  0.444444       NaN
# 50    NC    박석민  1985-06-22  172  ...  0.465753  0.612903  0.322581  0.285714
# 134   한화    최재훈  1989-08-27  135  ...  0.357143  0.437500  0.420290       NaN
# 114   키움     샌즈  1987-09-28  296  ...  0.507246  0.500000  0.293103  0.441860
# 69    두산    김재호  1985-03-21  139  ...  0.415094  0.442857  0.307692  0.666667
# 77    두산  페르난데스  1988-04-27  277  ...  0.363636  0.470000  0.452055  0.352941
# 65    SK     최정  1987-02-28  261  ...  0.405405  0.380000  0.409091  0.166667
# 21    KT    송민섭  1991-08-02   18  ...  0.125000  0.714286  0.166667       NaN
# 7    KIA    유민상  1989-04-13   81  ...  0.750000  0.454545  0.250000       NaN
# 72    두산    박건우  1990-09-08  219  ...  0.476190  0.425000  0.484848  0.227273
# 49    NC    박민우  1993-02-06  203  ...  0.441558  0.462500  0.410256  0.571429
# 109   키움    김하성  1995-10-17  283  ...  0.378788  0.456311  0.406780  0.346154
# 124   한화    김태균  1982-05-29  171  ...  0.342466  0.388889  0.327586       NaN
# 67    SK    한동민  1989-08-09  175  ...  0.430769  0.354839  0.483871  0.444444
# 83    롯데    민병헌  1987-03-10  167  ...  0.298507  0.377778  0.333333  0.250000
# 24    KT    유한준  1981-07-01  222  ...  0.555556  0.391304  0.490566       NaN
# 6    KIA    안치홍  1990-07-02  149  ...  0.342105  0.376471  0.000000       NaN
# 11   KIA     터커  1990-07-06  171  ...  0.618182  0.346154  0.407407       NaN
# 117   키움    이정후  1998-08-20  283  ...  0.369863  0.410714  0.516667  0.470588
# 34    LG    이천웅  1988-10-20  211  ...  0.389610  0.430000  0.375000  0.500000
# 61    SK     로맥  1985-09-30  263  ...  0.417910  0.375000  0.571429  0.357143
# 17    KT    로하스  1990-05-24  276  ...  0.375000  0.434343  0.362069       NaN
# 9    KIA    이창진  1991-03-04  153  ...  0.240000  0.404762  0.478261       NaN
# 86    롯데   아수아헤  1991-11-02   60  ...       NaN       NaN       NaN       NaN
# 115   키움    서건창  1989-08-22  180  ...       NaN  0.434783  0.396825  0.380000
# 74    두산    오재일  1986-10-29  236  ...  0.507692  0.418605  0.324675  0.347826
# 70    두산    김재환  1988-09-22  217  ...  0.285714  0.422535  0.408163  0.450000
# 42    NC    권희동  1990-12-30  124  ...  0.421053  0.454545  0.384615  0.500000
# 75    두산    정수빈  1990-10-07  151  ...  0.321429  0.349515  0.484848  0.550000
# 26    KT    조용호  1989-09-09   67  ...  0.402985  0.428571  0.250000       NaN
# 29    LG    김현수  1988-01-12  234  ...  0.492537  0.434343  0.190476  0.238095
# 111   키움    박동원  1990-04-07  143  ...  0.349206  0.470588  0.322581  0.200000
# 0    KIA    김선빈  1989-12-18  146  ...  0.512821  0.351648  0.414634       NaN
# 27    KT    황재균  1987-07-28  209  ...  0.482759  0.440000  0.468750       NaN
# 100   삼성    박계범  1996-01-11   65  ...       NaN  0.426230  0.338983       NaN
# 87    롯데     윌슨  1990-07-29  100  ...  0.500000  0.348315  0.387755       NaN
# 84    롯데    손아섭  1988-03-18  205  ...  0.359375  0.355932  0.389610  0.400000
# 97    삼성    김상수  1990-03-23  166  ...  0.410256  0.439394  0.181818       NaN
# 55    NC    이명기  1987-12-26  172  ...  0.361111  0.428571  0.371429  0.222222
# 98    삼성    김헌곤  1988-11-09  159  ...  0.536585  0.344828  0.392857       NaN
# 35    LG    이형종  1989-06-07  189  ...  0.358491  0.425287  0.328571  0.428571
# 113   키움    박정음  1989-04-15   21  ...  0.176471  0.454545  0.250000  0.357143
# 88    롯데    이대호  1982-06-21  211  ...  0.230769  0.448276  0.296296  0.500000
# 89    롯데    전준우  1986-02-25  262  ...  0.362319  0.361702  0.328358  0.000000
# 48    NC    모창민  1985-05-08  159  ...  0.437500  0.337500  0.300000  0.500000
#
# [50 rows x 23 columns]

# %%
# 출루율 관련 실적만 선택하겠습니다. 
df_selected = df_sort[['팀', '이름', '출루율', '03', '04', '05', '06', '07', '08', '09', '10']]
df_selected
# Out:
#        팀     이름       출루율        03  ...        07        08        09        10
# 46    NC    나성범  0.500000       NaN  ...       NaN       NaN       NaN       NaN
# 10   KIA    최형우  0.487234  0.366667  ...  0.509804  0.586207  0.611111       NaN
# 54    NC    양의지  0.486747  0.608696  ...  0.625000  0.476190  0.451613  0.333333
# 15    KT    강백호  0.472973  0.472222  ...       NaN  0.500000  0.437500       NaN
# 112   키움    박병호  0.465863  0.393939  ...  0.400000  0.434343  0.472727  0.437500
# 99    삼성     러프  0.461066  0.666667  ...  0.408451  0.411765  0.444444       NaN
# 50    NC    박석민  0.456464  0.571429  ...  0.465753  0.612903  0.322581  0.285714
# 134   한화    최재훈  0.455243  0.772727  ...  0.357143  0.437500  0.420290       NaN
# 114   키움     샌즈  0.452504  0.592593  ...  0.507246  0.500000  0.293103  0.441860
# 69    두산    김재호  0.450495  0.269231  ...  0.415094  0.442857  0.307692  0.666667
# 77    두산  페르난데스  0.448567  0.571429  ...  0.363636  0.470000  0.452055  0.352941
# 65    SK     최정  0.447706  0.333333  ...  0.405405  0.380000  0.409091  0.166667
# 21    KT    송민섭  0.438596  0.666667  ...  0.125000  0.714286  0.166667       NaN
# 7    KIA    유민상  0.438202       NaN  ...  0.750000  0.454545  0.250000       NaN
# 72    두산    박건우  0.438134  0.375000  ...  0.476190  0.425000  0.484848  0.227273
# 49    NC    박민우  0.436214       NaN  ...  0.441558  0.462500  0.410256  0.571429
# 109   키움    김하성  0.432612  0.483871  ...  0.378788  0.456311  0.406780  0.346154
# 124   한화    김태균  0.428251  0.642857  ...  0.342466  0.388889  0.327586       NaN
# 67    SK    한동민  0.424779  0.323529  ...  0.430769  0.354839  0.483871  0.444444
# 83    롯데    민병헌  0.421751  0.454545  ...  0.298507  0.377778  0.333333  0.250000
# 24    KT    유한준  0.421569  0.428571  ...  0.555556  0.391304  0.490566       NaN
# 6    KIA    안치홍  0.421196  0.517241  ...  0.342105  0.376471  0.000000       NaN
# 11   KIA     터커  0.421053       NaN  ...  0.618182  0.346154  0.407407       NaN
# 117   키움    이정후  0.419968  0.387097  ...  0.369863  0.410714  0.516667  0.470588
# 34    LG    이천웅  0.419580  0.363636  ...  0.389610  0.430000  0.375000  0.500000
# 61    SK     로맥  0.419355  0.206897  ...  0.417910  0.375000  0.571429  0.357143
# 17    KT    로하스  0.415879  0.451613  ...  0.375000  0.434343  0.362069       NaN
# 9    KIA    이창진  0.413203  0.000000  ...  0.240000  0.404762  0.478261       NaN
# 86    롯데   아수아헤  0.412121  0.518519  ...       NaN       NaN       NaN       NaN
# 115   키움    서건창  0.412008  0.354839  ...       NaN  0.434783  0.396825  0.380000
# 74    두산    오재일  0.408624  0.440000  ...  0.507692  0.418605  0.324675  0.347826
# 70    두산    김재환  0.407266  0.464286  ...  0.285714  0.422535  0.408163  0.450000
# 42    NC    권희동  0.406685  0.343750  ...  0.421053  0.454545  0.384615  0.500000
# 75    두산    정수빈  0.404711  0.521739  ...  0.321429  0.349515  0.484848  0.550000
# 26    KT    조용호  0.404255       NaN  ...  0.402985  0.428571  0.250000       NaN
# 29    LG    김현수  0.400356  0.344828  ...  0.492537  0.434343  0.190476  0.238095
# 111   키움    박동원  0.400000       NaN  ...  0.349206  0.470588  0.322581  0.200000
# 0    KIA    김선빈  0.398496  0.388889  ...  0.512821  0.351648  0.414634       NaN
# 27    KT    황재균  0.397802  0.285714  ...  0.482759  0.440000  0.468750       NaN
# 100   삼성    박계범  0.397727       NaN  ...       NaN  0.426230  0.338983       NaN
# 87    롯데     윌슨  0.396624       NaN  ...  0.500000  0.348315  0.387755       NaN
# 84    롯데    손아섭  0.396117  0.500000  ...  0.359375  0.355932  0.389610  0.400000
# 97    삼성    김상수  0.394251  0.615385  ...  0.410256  0.439394  0.181818       NaN
# 55    NC    이명기  0.393145  0.500000  ...  0.361111  0.428571  0.371429  0.222222
# 98    삼성    김헌곤  0.392941  0.324324  ...  0.536585  0.344828  0.392857       NaN
# 35    LG    이형종  0.392936  0.433333  ...  0.358491  0.425287  0.328571  0.428571
# 113   키움    박정음  0.390805       NaN  ...  0.176471  0.454545  0.250000  0.357143
# 88    롯데    이대호  0.388446  0.281250  ...  0.230769  0.448276  0.296296  0.500000
# 89    롯데    전준우  0.388193  0.303030  ...  0.362319  0.361702  0.328358  0.000000
# 48    NC    모창민  0.386555  0.500000  ...  0.437500  0.337500  0.300000  0.500000
#
# [50 rows x 11 columns]

# %%
# heatmap을 그리기 위하여 수치형이 아닌 부분은 index로 변경
df_selected = df_selected.set_index(['팀','이름'])
df_selected
# Out:
#                 출루율        03        04  ...        08        09        10
# 팀   이름                                   ...
# NC  나성범    0.500000       NaN  0.487805  ...       NaN       NaN       NaN
# KIA 최형우    0.487234  0.366667  0.414634  ...  0.586207  0.611111       NaN
# NC  양의지    0.486747  0.608696  0.448718  ...  0.476190  0.451613  0.333333
# KT  강백호    0.472973  0.472222  0.354167  ...  0.500000  0.437500       NaN
# 키움  박병호    0.465863  0.393939  0.656716  ...  0.434343  0.472727  0.437500
# 삼성  러프     0.461066  0.666667  0.471429  ...  0.411765  0.444444       NaN
# NC  박석민    0.456464  0.571429  0.434783  ...  0.612903  0.322581  0.285714
# 한화  최재훈    0.455243  0.772727  0.407407  ...  0.437500  0.420290       NaN
# 키움  샌즈     0.452504  0.592593  0.475248  ...  0.500000  0.293103  0.441860
# 두산  김재호    0.450495  0.269231  0.441176  ...  0.442857  0.307692  0.666667
#     페르난데스  0.448567  0.571429  0.494949  ...  0.470000  0.452055  0.352941
# SK  최정     0.447706  0.333333  0.530864  ...  0.380000  0.409091  0.166667
# KT  송민섭    0.438596  0.666667  0.000000  ...  0.714286  0.166667       NaN
# KIA 유민상    0.438202       NaN       NaN  ...  0.454545  0.250000       NaN
# 두산  박건우    0.438134  0.375000  0.412371  ...  0.425000  0.484848  0.227273
# NC  박민우    0.436214       NaN  0.403846  ...  0.462500  0.410256  0.571429
# 키움  김하성    0.432612  0.483871  0.464286  ...  0.456311  0.406780  0.346154
# 한화  김태균    0.428251  0.642857  0.450704  ...  0.388889  0.327586       NaN
# SK  한동민    0.424779  0.323529  0.475000  ...  0.354839  0.483871  0.444444
# 롯데  민병헌    0.421751  0.454545  0.642857  ...  0.377778  0.333333  0.250000
# KT  유한준    0.421569  0.428571  0.317647  ...  0.391304  0.490566       NaN
# KIA 안치홍    0.421196  0.517241  0.430556  ...  0.376471  0.000000       NaN
#     터커     0.421053       NaN       NaN  ...  0.346154  0.407407       NaN
# 키움  이정후    0.419968  0.387097  0.354167  ...  0.410714  0.516667  0.470588
# LG  이천웅    0.419580  0.363636  0.452381  ...  0.430000  0.375000  0.500000
# SK  로맥     0.419355  0.206897  0.386364  ...  0.375000  0.571429  0.357143
# KT  로하스    0.415879  0.451613  0.351064  ...  0.434343  0.362069       NaN
# KIA 이창진    0.413203  0.000000  0.450704  ...  0.404762  0.478261       NaN
# 롯데  아수아헤   0.412121  0.518519  0.394366  ...       NaN       NaN       NaN
# 키움  서건창    0.412008  0.354839  0.458333  ...  0.434783  0.396825  0.380000
# 두산  오재일    0.408624  0.440000  0.339286  ...  0.418605  0.324675  0.347826
#     김재환    0.407266  0.464286  0.446809  ...  0.422535  0.408163  0.450000
# NC  권희동    0.406685  0.343750  0.349398  ...  0.454545  0.384615  0.500000
# 두산  정수빈    0.404711  0.521739  0.469880  ...  0.349515  0.484848  0.550000
# KT  조용호    0.404255       NaN       NaN  ...  0.428571  0.250000       NaN
# LG  김현수    0.400356  0.344828  0.524390  ...  0.434343  0.190476  0.238095
# 키움  박동원    0.400000       NaN  0.500000  ...  0.470588  0.322581  0.200000
# KIA 김선빈    0.398496  0.388889  0.363636  ...  0.351648  0.414634       NaN
# KT  황재균    0.397802  0.285714  0.358696  ...  0.440000  0.468750       NaN
# 삼성  박계범    0.397727       NaN  0.500000  ...  0.426230  0.338983       NaN
# 롯데  윌슨     0.396624       NaN       NaN  ...  0.348315  0.387755       NaN
#     손아섭    0.396117  0.500000  0.426667  ...  0.355932  0.389610  0.400000
# 삼성  김상수    0.394251  0.615385  0.336957  ...  0.439394  0.181818       NaN
# NC  이명기    0.393145  0.500000  0.438356  ...  0.428571  0.371429  0.222222
# 삼성  김헌곤    0.392941  0.324324  0.270833  ...  0.344828  0.392857       NaN
# LG  이형종    0.392936  0.433333  0.450000  ...  0.425287  0.328571  0.428571
# 키움  박정음    0.390805       NaN  0.473684  ...  0.454545  0.250000  0.357143
# 롯데  이대호    0.388446  0.281250  0.411765  ...  0.448276  0.296296  0.500000
#     전준우    0.388193  0.303030  0.420455  ...  0.361702  0.328358  0.000000
# NC  모창민    0.386555  0.500000  0.384615  ...  0.337500  0.300000  0.500000
#
# [50 rows x 9 columns]

# %%
# colab 한글폰트 사용 설정

import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 11 not upgraded.

# %%
import seaborn as sns
sns.heatmap(df_selected)

# %%
# 월별 출루율을 히트맵으로 그려보겠습니다. 
# 출루율 실적을 히트맵에 표현하고,  컬러맵은 Reds 를 활용하여 출루율이 높을 수록 붉은색이 진하게 표현되도록 하였습니다. 

fig,ax = plt.subplots(figsize=(10,10))

sns.heatmap(df_selected, 
            annot=True,
            fmt='.3f',
            cmap='Reds'
            )

# %%
# 월별 출루율을  시즌 출루율 대비한 +- 값으로 변경하여, 월별 변화 정도를 살펴보겠습니다. 
# 시즌 전체 대비 월별 실적 

for col in df_selected.columns[1:]:
  df_selected[col] = df_selected[col] - df_selected['출루율']

df_selected['출루율'] = 0.0
df_selected
# Out:
#            출루율        03        04  ...        08        09        10
# 팀   이름                              ...
# NC  나성범    0.0       NaN -0.012195  ...       NaN       NaN       NaN
# KIA 최형우    0.0 -0.120567 -0.072600  ...  0.098973  0.123877       NaN
# NC  양의지    0.0  0.121949 -0.038029  ... -0.010557 -0.035134 -0.153414
# KT  강백호    0.0 -0.000751 -0.118806  ...  0.027027 -0.035473       NaN
# 키움  박병호    0.0 -0.071924  0.190853  ... -0.031520  0.006864 -0.028363
# 삼성  러프     0.0  0.205601  0.010363  ... -0.049301 -0.016621       NaN
# NC  박석민    0.0  0.114964 -0.021682  ...  0.156439 -0.133884 -0.170750
# 한화  최재훈    0.0  0.317484 -0.047836  ... -0.017743 -0.034953       NaN
# 키움  샌즈     0.0  0.140088  0.022743  ...  0.047496 -0.159401 -0.010644
# 두산  김재호    0.0 -0.181264 -0.009319  ... -0.007638 -0.142803  0.216172
#     페르난데스  0.0  0.122862  0.046383  ...  0.021433  0.003488 -0.095625
# SK  최정     0.0 -0.114373  0.083158  ... -0.067706 -0.038616 -0.281040
# KT  송민섭    0.0  0.228070 -0.438596  ...  0.275689 -0.271930       NaN
# KIA 유민상    0.0       NaN       NaN  ...  0.016343 -0.188202       NaN
# 두산  박건우    0.0 -0.063134 -0.025763  ... -0.013134  0.046715 -0.210861
# NC  박민우    0.0       NaN -0.032368  ...  0.026286 -0.025958  0.135215
# 키움  김하성    0.0  0.051259  0.031673  ...  0.023698 -0.025833 -0.086458
# 한화  김태균    0.0  0.214606  0.022453  ... -0.039362 -0.100665       NaN
# SK  한동민    0.0 -0.101249  0.050221  ... -0.069940  0.059092  0.019666
# 롯데  민병헌    0.0  0.032795  0.221106  ... -0.043973 -0.088417 -0.171751
# KT  유한준    0.0  0.007003 -0.103922  ... -0.030264  0.068997       NaN
# KIA 안치홍    0.0  0.096046  0.009360  ... -0.044725 -0.421196       NaN
#     터커     0.0       NaN       NaN  ... -0.074899 -0.013645       NaN
# 키움  이정후    0.0 -0.032872 -0.065802  ... -0.009254  0.096698  0.050620
# LG  이천웅    0.0 -0.055944  0.032801  ...  0.010420 -0.044580  0.080420
# SK  로맥     0.0 -0.212458 -0.032991  ... -0.044355  0.152074 -0.062212
# KT  로하스    0.0  0.035734 -0.064815  ...  0.018464 -0.053810       NaN
# KIA 이창진    0.0 -0.413203  0.037501  ... -0.008441  0.065058       NaN
# 롯데  아수아헤   0.0  0.106397 -0.017755  ...       NaN       NaN       NaN
# 키움  서건창    0.0 -0.057170  0.046325  ...  0.022774 -0.015183 -0.032008
# 두산  오재일    0.0  0.031376 -0.069339  ...  0.009980 -0.083949 -0.060798
#     김재환    0.0  0.057020  0.039543  ...  0.015269  0.000897  0.042734
# NC  권희동    0.0 -0.062935 -0.057288  ...  0.047860 -0.022070  0.093315
# 두산  정수빈    0.0  0.117028  0.065169  ... -0.055196  0.080138  0.145289
# KT  조용호    0.0       NaN       NaN  ...  0.024316 -0.154255       NaN
# LG  김현수    0.0 -0.055528  0.124034  ...  0.033988 -0.209880 -0.162261
# 키움  박동원    0.0       NaN  0.100000  ...  0.070588 -0.077419 -0.200000
# KIA 김선빈    0.0 -0.009607 -0.034860  ... -0.046848  0.016138       NaN
# KT  황재균    0.0 -0.112088 -0.039107  ...  0.042198  0.070948       NaN
# 삼성  박계범    0.0       NaN  0.102273  ...  0.028502 -0.058744       NaN
# 롯데  윌슨     0.0       NaN       NaN  ... -0.048310 -0.008869       NaN
#     손아섭    0.0  0.103883  0.030550  ... -0.040184 -0.006506  0.003883
# 삼성  김상수    0.0  0.221134 -0.057294  ...  0.045143 -0.212432       NaN
# NC  이명기    0.0  0.106855  0.045211  ...  0.035426 -0.021717 -0.170923
# 삼성  김헌곤    0.0 -0.068617 -0.122108  ... -0.048114 -0.000084       NaN
# LG  이형종    0.0  0.040397  0.057064  ...  0.032351 -0.064365  0.035635
# 키움  박정음    0.0       NaN  0.082880  ...  0.063741 -0.140805 -0.033662
# 롯데  이대호    0.0 -0.107196  0.023318  ...  0.059830 -0.092150  0.111554
#     전준우    0.0 -0.085163  0.032261  ... -0.026491 -0.059835 -0.388193
# NC  모창민    0.0  0.113445 -0.001939  ... -0.049055 -0.086555  0.113445
#
# [50 rows x 9 columns]

# %%
#  시즌 전체 대비 월별 출루율 증감 실적을 히트맵으로 표현해보겠습니다.
# 이번에는 컬러맵을 Blue ~ Red 로 나타내기 위해 RdBu_r 로 지정하였습니다. 

# 그림 사이즈 지정
fig, ax = plt.subplots( figsize=(10,10) )

sns.heatmap(data = df_selected.head(50), 
            annot = True, fmt = '.3f', 
            cmap = 'RdBu_r'
           )
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
